# %% [markdown]
# ### Main imports

# %%
import os
import requests
from tqdm import tqdm
import zipfile
import numpy as np
import torch
import torch.optim as optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
import matplotlib.pyplot as plt
from IPython import display as disp
from pathlib import Path

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print('Device:', device.type)
print('Imports complete.')
# Out:
# Device: cuda
# Imports complete.

# %% [markdown]
# ### Import dataset

# %%
import os
import numpy
import torch
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt

# directory where the data is stored
data_dir = 'classification-data'

# the .npy files
train_x_path = os.path.join(data_dir, 'train_x.npy')
train_y_path = os.path.join(data_dir, 'train_y.npy')
valid_x_path = os.path.join(data_dir, 'valid_x.npy')
valid_y_path = os.path.join(data_dir, 'valid_y.npy')
test_x_path = os.path.join(data_dir, 'test_x.npy')
test_y_path = os.path.join(data_dir, 'test_y.npy')

# load the data
print("Loading data...")
train_x = numpy.load(train_x_path)
train_y = numpy.load(train_y_path)
valid_x = numpy.load(valid_x_path)
valid_y = numpy.load(valid_y_path)
test_x = numpy.load(test_x_path)
test_y = numpy.load(test_y_path)
print("Data loaded successfully.")

print("Shape of one training sample:", train_x.shape[1:])
print("Shape of one validation sample:", valid_x.shape[1:])
print("Shape of one test sample:", test_x.shape[1:])

train_x = train_x.reshape(-1, 3, 28, 28) 
valid_x = valid_x.reshape(-1, 3, 28, 28) 
test_x = test_x.reshape(-1, 3, 28, 28)

print("Shape of one training sample:", train_x.shape[1:])
print("Shape of one validation sample:", valid_x.shape[1:])
print("Shape of one test sample:", test_x.shape[1:])

# convert NumPy arrays to PyTorch tensors - HAS BEEN CHANGED FOR THE ABOVE
train_x = torch.from_numpy(train_x).float()
train_y = torch.from_numpy(train_y).long()
valid_x = torch.from_numpy(valid_x).float()

valid_y = torch.from_numpy(valid_y).long()
test_x = torch.from_numpy(test_x).float()
test_y = torch.from_numpy(test_y).long()

# create TensorDataset instances
train_dataset = TensorDataset(train_x, train_y)
valid_dataset = TensorDataset(valid_x, valid_y)
test_dataset = TensorDataset(test_x, test_y)

# batch size
batch_size = 64

# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False, drop_last=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

# Helper function to cycle through the data indefinitely
def cycle(iterable):
    while True:
        for x in iterable:
            yield x

# iterators for training, validation, and test loaders
train_iterator = iter(cycle(train_loader))
valid_iterator = iter(cycle(valid_loader))
test_iterator = iter(cycle(test_loader))

# class names
class_names = [str(i) for i in range(20)]

# dataset sizes
print(f'> Size of training dataset: {len(train_dataset)}')
print(f'> Size of validation dataset: {len(valid_dataset)}')
print(f'> Size of test dataset: {len(test_dataset)}')

num_batches_per_epoch = len(train_loader) // batch_size

num_of_epochs = 50000 // num_batches_per_epoch

print(f'Number of batches per epoch: {num_batches_per_epoch}')
print(f'Number of epochs: {num_of_epochs}')
# Out:
# Loading data...
# Data loaded successfully.
# Shape of one training sample: (3, 28, 28)
# Shape of one validation sample: (3, 28, 28)
# Shape of one test sample: (3, 28, 28)
# Shape of one training sample: (3, 28, 28)
# Shape of one validation sample: (3, 28, 28)
# Shape of one test sample: (3, 28, 28)
# > Size of training dataset: 45000
# > Size of validation dataset: 15000
# > Size of test dataset: 10000
# Number of batches per epoch: 10
# Number of epochs: 5000

# %% [markdown]
# **View some of the test dataset**

# %%
plt.rcParams['figure.dpi'] = 70
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    img = test_loader.dataset[i][0].numpy().transpose(1, 2, 0)
    img = numpy.clip(img, 0, 1)
    plt.imshow(img)
    plt.xlabel(class_names[test_loader.dataset[i][1]])
plt.show()

# %% [markdown]
# ### Resnet Model

# %%
class EfficientResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(EfficientResidualBlock, self).__init__()
        # Reduced intermediate channels by using a bottleneck design
        mid_channels = out_channels // 4
        
        self.conv1 = nn.Conv2d(in_channels, mid_channels, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(mid_channels)
        self.conv2 = nn.Conv2d(mid_channels, mid_channels, kernel_size=3,
                              stride=stride, padding=1, groups=mid_channels, bias=False)
        self.bn2 = nn.BatchNorm2d(mid_channels)
        self.conv3 = nn.Conv2d(mid_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1,
                         stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        residual = x
        
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        
        out += self.shortcut(residual)
        out = F.relu(out)
        
        return out

class EfficientResNet32x32(nn.Module):
    def __init__(self, num_classes=10):
        super(EfficientResNet32x32, self).__init__()
        
        # Reduced initial channels
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        
        # Reduced channel dimensions throughout
        self.layer1 = self._make_layer(32, 64, stride=1)
        self.layer2 = self._make_layer(64, 128, stride=2)
        self.layer3 = self._make_layer(128, 256, stride=2)
        
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(256, num_classes)

    def _make_layer(self, in_channels, out_channels, stride):
        return nn.Sequential(
            EfficientResidualBlock(in_channels, out_channels, stride),
            EfficientResidualBlock(out_channels, out_channels, 1)
        )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.avg_pool(out)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

def create_model(num_classes=100, device='cuda'):
    model = EfficientResNet32x32(num_classes=num_classes)
    model = model.to(device)
    
    # Define optimizer and loss function
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()
    
    return model, optimizer, criterion

model, optimizer, criterion = create_model(num_classes=100, device=device)

print("Parameter count:", sum(p.numel() for p in model.parameters() if p.requires_grad))
# Out:
# Parameter count: 150500

# %% [markdown]
# ### Main training and testing loop - Attempt 1

# %%
save_dir = Path('checkpoints')
save_dir.mkdir(exist_ok=True)
best_acc = 0.0
epoch = 0
batch_size = train_loader.batch_size
check_interval = 5

# training loop
while (epoch < num_of_epochs):
    model.train()
    
    # arrays for metrics
    logs = {}
    train_loss_arr = np.zeros(0)
    train_acc_arr = np.zeros(0)
    
    # iterate over the train dataset
    for i, batch in enumerate(train_loader):
        x, t = batch
        x, t = x.to(device), t.to(device)
        
        # forward pass
        outputs = model(x)
        loss = criterion(outputs, t)
        
        # backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # calculate accuracy
        _, predicted = outputs.max(1)
        accuracy = predicted.eq(t).sum().item() / t.size(0) * 100
        
        # store metrics
        train_loss_arr = np.append(train_loss_arr, loss.item())
        train_acc_arr = np.append(train_acc_arr, accuracy)
        
        print(f'Epoch [{epoch+1}/{num_of_epochs}], Batch [{i+1}/{len(train_loader)}], '
                f'Loss: {train_loss_arr.mean():.4f}, Accuracy: {train_acc_arr.mean():.2f}%')
    
    # validation check at specified intervals
    if (epoch + 1) % check_interval == 0:
        model.eval()
        val_loss_arr = np.zeros(0)
        val_acc_arr = np.zeros(0)
        
        with torch.no_grad():
            for val_x, val_t in test_loader: # this might be incorrect for the loop
                val_x, val_t = val_x.to(device), val_t.to(device)
                val_outputs = model(val_x)
                val_loss = criterion(val_outputs, val_t)
                
                _, val_predicted = val_outputs.max(1)
                val_accuracy = val_predicted.eq(val_t).sum().item() / val_t.size(0) * 100
                
                val_loss_arr = np.append(val_loss_arr, val_loss.item())
                val_acc_arr = np.append(val_acc_arr, val_accuracy)
            
            print(f'\nValidation at Epoch [{epoch+1}/{num_of_epochs}], '
                    f'Loss: {val_loss_arr.mean():.4f}, Accuracy: {val_acc_arr.mean():.2f}%')
            
            # save best model
            if val_acc_arr.mean() > best_acc:
                best_acc = val_acc_arr.mean()
                checkpoint = {
                    'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'accuracy': best_acc,
                }
                torch.save(checkpoint, save_dir / 'best_model.pth')
                print(f'New best validation accuracy: {best_acc:.2f}%')
            
            # visualize random batch of training images
            plt.figure(figsize=(10, 10))
            plt.axis('off')
            plt.title(f'Training Images at Epoch {epoch+1}')
            plt.imshow(np.transpose(
                torchvision.utils.make_grid(x[:batch_size], padding=2, normalize=True).cpu(),
                (1, 2, 0)
            ))
            plt.show()
        
        model.train()
    
    print(f"Epoch {epoch} finished!")
    epoch += 1

print('\nTraining completed!')
print(f'Best validation accuracy: {best_acc:.2f}%')
# Out:
# Epoch [1/5000], Batch [1/703], Loss: 4.7449, Accuracy: 0.00%
# Epoch [1/5000], Batch [2/703], Loss: 4.5442, Accuracy: 0.00%
# Epoch [1/5000], Batch [3/703], Loss: 4.3864, Accuracy: 2.08%
# Epoch [1/5000], Batch [4/703], Loss: 4.2584, Accuracy: 3.52%
# Epoch [1/5000], Batch [5/703], Loss: 4.1428, Accuracy: 3.75%
# Epoch [1/5000], Batch [6/703], Loss: 4.0468, Accuracy: 3.65%
# Epoch [1/5000], Batch [7/703], Loss: 3.9494, Accuracy: 3.79%
# Epoch [1/5000], Batch [8/703], Loss: 3.8627, Accuracy: 4.30%
# Epoch [1/5000], Batch [9/703], Loss: 3.7866, Accuracy: 3.99%
# Epoch [1/5000], Batch [10/703], Loss: 3.7205, Accuracy: 3.91%
# Epoch [1/5000], Batch [11/703], Loss: 3.6664, Accuracy: 4.26%
# Epoch [1/5000], Batch [12/703], Loss: 3.6223, Accuracy: 4.17%
# Epoch [1/5000], Batch [13/703], Loss: 3.5811, Accuracy: 4.33%
# Epoch [1/5000], Batch [14/703], Loss: 3.5441, Accuracy: 4.35%
# Epoch [1/5000], Batch [15/703], Loss: 3.5141, Accuracy: 4.69%
# Epoch [1/5000], Batch [16/703], Loss: 3.4854, Accuracy: 4.69%
# Epoch [1/5000], Batch [17/703], Loss: 3.4598, Accuracy: 4.41%
# Epoch [1/5000], Batch [18/703], Loss: 3.4372, Accuracy: 4.34%
# Epoch [1/5000], Batch [56/703], Loss: 3.1453, Accuracy: 5.11%
# Epoch [1/5000], Batch [57/703], Loss: 3.1436, Accuracy: 5.04%
# Epoch [1/5000], Batch [58/703], Loss: 3.1402, Accuracy: 5.04%
# Epoch [1/5000], Batch [59/703], Loss: 3.1393, Accuracy: 5.01%
# Epoch [1/5000], Batch [60/703], Loss: 3.1356, Accuracy: 5.05%
# Epoch [1/5000], Batch [61/703], Loss: 3.1327, Accuracy: 5.20%
# Epoch [1/5000], Batch [62/703], Loss: 3.1297, Accuracy: 5.27%
# Epoch [1/5000], Batch [63/703], Loss: 3.1265, Accuracy: 5.31%
# Epoch [1/5000], Batch [64/703], Loss: 3.1248, Accuracy: 5.25%
# Epoch [1/5000], Batch [65/703], Loss: 3.1220, Accuracy: 5.36%
# Epoch [1/5000], Batch [66/703], Loss: 3.1195, Accuracy: 5.47%
# Epoch [1/5000], Batch [67/703], Loss: 3.1167, Accuracy: 5.46%
# Epoch [1/5000], Batch [68/703], Loss: 3.1147, Accuracy: 5.49%
# Epoch [1/5000], Batch [69/703], Loss: 3.1130, Accuracy: 5.55%
# Epoch [1/5000], Batch [70/703], Loss: 3.1104, Accuracy: 5.56%
# Epoch [1/5000], Batch [71/703], Loss: 3.1077, Accuracy: 5.57%
# Epoch [1/5000], Batch [72/703], Loss: 3.1051, Accuracy: 5.71%
# Epoch [1/5000], Batch [73/703], Loss: 3.1012, Accuracy: 5.89%
# Epoch [1/5000], Batch [74/703], Loss: 3.0989, Accuracy: 5.91%
# Epoch [1/5000], Batch [75/703], Loss: 3.0951, Accuracy: 6.00%
# Epoch [1/5000], Batch [76/703], Loss: 3.0915, Accuracy: 6.11%
# Epoch [1/5000], Batch [77/703], Loss: 3.0886, Accuracy: 6.13%
# Epoch [1/5000], Batch [78/703], Loss: 3.0863, Accuracy: 6.09%
# Epoch [1/5000], Batch [79/703], Loss: 3.0836, Accuracy: 6.11%
# Epoch [1/5000], Batch [80/703], Loss: 3.0813, Accuracy: 6.15%
# Epoch [1/5000], Batch [81/703], Loss: 3.0795, Accuracy: 6.13%
# Epoch [1/5000], Batch [82/703], Loss: 3.0774, Accuracy: 6.19%
# Epoch [1/5000], Batch [83/703], Loss: 3.0748, Accuracy: 6.27%
# Epoch [1/5000], Batch [84/703], Loss: 3.0720, Accuracy: 6.29%
# Epoch [1/5000], Batch [85/703], Loss: 3.0701, Accuracy: 6.40%
# Epoch [1/5000], Batch [86/703], Loss: 3.0677, Accuracy: 6.43%
# Epoch [1/5000], Batch [87/703], Loss: 3.0646, Accuracy: 6.52%
# Epoch [1/5000], Batch [88/703], Loss: 3.0621, Accuracy: 6.55%
# Epoch [1/5000], Batch [89/703], Loss: 3.0600, Accuracy: 6.58%
# Epoch [1/5000], Batch [90/703], Loss: 3.0573, Accuracy: 6.67%
# Epoch [1/5000], Batch [91/703], Loss: 3.0546, Accuracy: 6.68%
# Epoch [1/5000], Batch [92/703], Loss: 3.0523, Accuracy: 6.71%
# Epoch [1/5000], Batch [130/703], Loss: 2.9650, Accuracy: 8.09%
# Epoch [1/5000], Batch [131/703], Loss: 2.9629, Accuracy: 8.11%
# Epoch [1/5000], Batch [132/703], Loss: 2.9606, Accuracy: 8.13%
# Epoch [1/5000], Batch [133/703], Loss: 2.9580, Accuracy: 8.19%
# Epoch [1/5000], Batch [134/703], Loss: 2.9569, Accuracy: 8.16%
# Epoch [1/5000], Batch [135/703], Loss: 2.9556, Accuracy: 8.21%
# Epoch [1/5000], Batch [136/703], Loss: 2.9532, Accuracy: 8.27%
# Epoch [1/5000], Batch [137/703], Loss: 2.9509, Accuracy: 8.29%
# Epoch [1/5000], Batch [138/703], Loss: 2.9487, Accuracy: 8.29%
# Epoch [1/5000], Batch [139/703], Loss: 2.9461, Accuracy: 8.35%
# Epoch [1/5000], Batch [140/703], Loss: 2.9438, Accuracy: 8.39%
# Epoch [1/5000], Batch [141/703], Loss: 2.9423, Accuracy: 8.37%
# Epoch [1/5000], Batch [142/703], Loss: 2.9411, Accuracy: 8.35%
# Epoch [1/5000], Batch [143/703], Loss: 2.9387, Accuracy: 8.38%
# Epoch [1/5000], Batch [144/703], Loss: 2.9371, Accuracy: 8.41%
# Epoch [1/5000], Batch [145/703], Loss: 2.9347, Accuracy: 8.47%
# Epoch [1/5000], Batch [146/703], Loss: 2.9320, Accuracy: 8.50%
# Epoch [1/5000], Batch [147/703], Loss: 2.9304, Accuracy: 8.49%
# Epoch [1/5000], Batch [148/703], Loss: 2.9282, Accuracy: 8.54%
# Epoch [1/5000], Batch [149/703], Loss: 2.9267, Accuracy: 8.56%
# Epoch [1/5000], Batch [150/703], Loss: 2.9252, Accuracy: 8.58%
# Epoch [1/5000], Batch [151/703], Loss: 2.9243, Accuracy: 8.60%
# Epoch [1/5000], Batch [152/703], Loss: 2.9220, Accuracy: 8.65%
# Epoch [1/5000], Batch [153/703], Loss: 2.9203, Accuracy: 8.67%
# Epoch [1/5000], Batch [154/703], Loss: 2.9193, Accuracy: 8.65%
# Epoch [1/5000], Batch [155/703], Loss: 2.9175, Accuracy: 8.69%
# Epoch [1/5000], Batch [156/703], Loss: 2.9157, Accuracy: 8.73%
# Epoch [1/5000], Batch [157/703], Loss: 2.9138, Accuracy: 8.76%
# Epoch [1/5000], Batch [158/703], Loss: 2.9123, Accuracy: 8.77%
# Epoch [1/5000], Batch [159/703], Loss: 2.9105, Accuracy: 8.78%
# Epoch [1/5000], Batch [160/703], Loss: 2.9083, Accuracy: 8.85%
# Epoch [1/5000], Batch [161/703], Loss: 2.9065, Accuracy: 8.87%
# Epoch [1/5000], Batch [162/703], Loss: 2.9049, Accuracy: 8.89%
# Epoch [1/5000], Batch [163/703], Loss: 2.9024, Accuracy: 8.93%
# Epoch [1/5000], Batch [164/703], Loss: 2.9000, Accuracy: 9.01%
# Epoch [1/5000], Batch [165/703], Loss: 2.8984, Accuracy: 9.11%
# Epoch [1/5000], Batch [166/703], Loss: 2.8963, Accuracy: 9.17%
# Epoch [1/5000], Batch [167/703], Loss: 2.8945, Accuracy: 9.21%
# Epoch [1/5000], Batch [168/703], Loss: 2.8929, Accuracy: 9.23%
# Epoch [1/5000], Batch [169/703], Loss: 2.8909, Accuracy: 9.27%
# Epoch [1/5000], Batch [170/703], Loss: 2.8887, Accuracy: 9.32%
# Epoch [1/5000], Batch [171/703], Loss: 2.8872, Accuracy: 9.34%
# Epoch [1/5000], Batch [172/703], Loss: 2.8853, Accuracy: 9.38%
# Epoch [1/5000], Batch [173/703], Loss: 2.8829, Accuracy: 9.41%
# Epoch [1/5000], Batch [174/703], Loss: 2.8811, Accuracy: 9.45%
# Epoch [1/5000], Batch [175/703], Loss: 2.8793, Accuracy: 9.49%
# Epoch [1/5000], Batch [176/703], Loss: 2.8778, Accuracy: 9.53%
# Epoch [1/5000], Batch [177/703], Loss: 2.8767, Accuracy: 9.56%
# Epoch [1/5000], Batch [178/703], Loss: 2.8747, Accuracy: 9.59%
# Epoch [1/5000], Batch [179/703], Loss: 2.8731, Accuracy: 9.60%
# Epoch [1/5000], Batch [180/703], Loss: 2.8712, Accuracy: 9.62%
# Epoch [1/5000], Batch [181/703], Loss: 2.8697, Accuracy: 9.63%
# Epoch [1/5000], Batch [182/703], Loss: 2.8677, Accuracy: 9.62%
# Epoch [1/5000], Batch [183/703], Loss: 2.8667, Accuracy: 9.63%
# Epoch [1/5000], Batch [184/703], Loss: 2.8646, Accuracy: 9.68%
# Epoch [1/5000], Batch [185/703], Loss: 2.8631, Accuracy: 9.70%
# Epoch [1/5000], Batch [186/703], Loss: 2.8618, Accuracy: 9.72%
# Epoch [1/5000], Batch [187/703], Loss: 2.8606, Accuracy: 9.70%
# Epoch [1/5000], Batch [188/703], Loss: 2.8593, Accuracy: 9.72%
# Epoch [1/5000], Batch [189/703], Loss: 2.8578, Accuracy: 9.73%
# Epoch [1/5000], Batch [190/703], Loss: 2.8566, Accuracy: 9.72%
# Epoch [1/5000], Batch [191/703], Loss: 2.8556, Accuracy: 9.71%
# Epoch [1/5000], Batch [192/703], Loss: 2.8549, Accuracy: 9.72%
# Epoch [1/5000], Batch [193/703], Loss: 2.8535, Accuracy: 9.71%
# Epoch [1/5000], Batch [194/703], Loss: 2.8519, Accuracy: 9.70%
# Epoch [1/5000], Batch [195/703], Loss: 2.8508, Accuracy: 9.72%
# Epoch [1/5000], Batch [196/703], Loss: 2.8492, Accuracy: 9.74%
# Epoch [1/5000], Batch [197/703], Loss: 2.8484, Accuracy: 9.76%
# Epoch [1/5000], Batch [198/703], Loss: 2.8465, Accuracy: 9.82%
# Epoch [1/5000], Batch [199/703], Loss: 2.8447, Accuracy: 9.87%
# Epoch [1/5000], Batch [200/703], Loss: 2.8436, Accuracy: 9.88%
# Epoch [1/5000], Batch [201/703], Loss: 2.8427, Accuracy: 9.90%
# Epoch [1/5000], Batch [202/703], Loss: 2.8416, Accuracy: 9.92%
# Epoch [1/5000], Batch [203/703], Loss: 2.8401, Accuracy: 9.94%
# Epoch [1/5000], Batch [204/703], Loss: 2.8384, Accuracy: 9.93%
# Epoch [1/5000], Batch [205/703], Loss: 2.8367, Accuracy: 9.94%
# Epoch [1/5000], Batch [206/703], Loss: 2.8343, Accuracy: 10.02%
# Epoch [1/5000], Batch [207/703], Loss: 2.8329, Accuracy: 10.05%
# Epoch [1/5000], Batch [208/703], Loss: 2.8314, Accuracy: 10.08%
# Epoch [1/5000], Batch [209/703], Loss: 2.8299, Accuracy: 10.09%
# Epoch [1/5000], Batch [210/703], Loss: 2.8288, Accuracy: 10.07%
# Epoch [1/5000], Batch [211/703], Loss: 2.8270, Accuracy: 10.08%
# Epoch [1/5000], Batch [212/703], Loss: 2.8254, Accuracy: 10.07%
# Epoch [1/5000], Batch [213/703], Loss: 2.8238, Accuracy: 10.07%
# Epoch [1/5000], Batch [214/703], Loss: 2.8225, Accuracy: 10.09%
# Epoch [1/5000], Batch [215/703], Loss: 2.8212, Accuracy: 10.12%
# Epoch [1/5000], Batch [216/703], Loss: 2.8206, Accuracy: 10.11%
# Epoch [1/5000], Batch [217/703], Loss: 2.8190, Accuracy: 10.16%
# Epoch [1/5000], Batch [218/703], Loss: 2.8170, Accuracy: 10.24%
# Epoch [1/5000], Batch [219/703], Loss: 2.8157, Accuracy: 10.27%
# Epoch [1/5000], Batch [220/703], Loss: 2.8136, Accuracy: 10.33%
# Epoch [1/5000], Batch [221/703], Loss: 2.8118, Accuracy: 10.38%
# Epoch [1/5000], Batch [222/703], Loss: 2.8103, Accuracy: 10.39%
# Epoch [1/5000], Batch [223/703], Loss: 2.8092, Accuracy: 10.40%
# Epoch [1/5000], Batch [224/703], Loss: 2.8084, Accuracy: 10.42%
# Epoch [1/5000], Batch [225/703], Loss: 2.8066, Accuracy: 10.44%
# Epoch [1/5000], Batch [226/703], Loss: 2.8052, Accuracy: 10.44%
# Epoch [1/5000], Batch [227/703], Loss: 2.8036, Accuracy: 10.45%
# Epoch [1/5000], Batch [228/703], Loss: 2.8026, Accuracy: 10.46%
# Epoch [1/5000], Batch [229/703], Loss: 2.8014, Accuracy: 10.48%
# Epoch [1/5000], Batch [230/703], Loss: 2.8001, Accuracy: 10.49%
# Epoch [1/5000], Batch [231/703], Loss: 2.7991, Accuracy: 10.52%
# Epoch [1/5000], Batch [232/703], Loss: 2.7973, Accuracy: 10.56%
# Epoch [1/5000], Batch [233/703], Loss: 2.7961, Accuracy: 10.56%
# Epoch [1/5000], Batch [234/703], Loss: 2.7944, Accuracy: 10.61%
# Epoch [1/5000], Batch [235/703], Loss: 2.7928, Accuracy: 10.65%
# Epoch [1/5000], Batch [236/703], Loss: 2.7911, Accuracy: 10.70%
# Epoch [1/5000], Batch [237/703], Loss: 2.7895, Accuracy: 10.73%
# Epoch [1/5000], Batch [238/703], Loss: 2.7883, Accuracy: 10.76%
# Epoch [1/5000], Batch [239/703], Loss: 2.7872, Accuracy: 10.76%
# Epoch [1/5000], Batch [240/703], Loss: 2.7862, Accuracy: 10.80%
# Epoch [1/5000], Batch [464/703], Loss: 2.5870, Accuracy: 14.47%
# Epoch [1/5000], Batch [465/703], Loss: 2.5867, Accuracy: 14.47%
# Epoch [1/5000], Batch [466/703], Loss: 2.5866, Accuracy: 14.47%
# Epoch [1/5000], Batch [467/703], Loss: 2.5862, Accuracy: 14.47%
# Epoch [1/5000], Batch [468/703], Loss: 2.5853, Accuracy: 14.50%
# Epoch [1/5000], Batch [469/703], Loss: 2.5849, Accuracy: 14.50%
# Epoch [1/5000], Batch [470/703], Loss: 2.5847, Accuracy: 14.51%
# Epoch [1/5000], Batch [471/703], Loss: 2.5843, Accuracy: 14.53%
# Epoch [1/5000], Batch [472/703], Loss: 2.5838, Accuracy: 14.54%
# Epoch [1/5000], Batch [473/703], Loss: 2.5829, Accuracy: 14.55%
# Epoch [1/5000], Batch [474/703], Loss: 2.5822, Accuracy: 14.57%
# Epoch [1/5000], Batch [475/703], Loss: 2.5814, Accuracy: 14.60%
# Epoch [1/5000], Batch [476/703], Loss: 2.5807, Accuracy: 14.62%
# Epoch [1/5000], Batch [477/703], Loss: 2.5802, Accuracy: 14.63%
# Epoch [1/5000], Batch [478/703], Loss: 2.5793, Accuracy: 14.64%
# Epoch [1/5000], Batch [479/703], Loss: 2.5786, Accuracy: 14.65%
# Epoch [1/5000], Batch [480/703], Loss: 2.5776, Accuracy: 14.69%
# Epoch [1/5000], Batch [481/703], Loss: 2.5768, Accuracy: 14.71%
# Epoch [1/5000], Batch [482/703], Loss: 2.5760, Accuracy: 14.74%
# Epoch [1/5000], Batch [483/703], Loss: 2.5755, Accuracy: 14.75%
# Epoch [1/5000], Batch [484/703], Loss: 2.5748, Accuracy: 14.79%
# Epoch [1/5000], Batch [485/703], Loss: 2.5741, Accuracy: 14.80%
# Epoch [1/5000], Batch [486/703], Loss: 2.5739, Accuracy: 14.80%
# Epoch [1/5000], Batch [487/703], Loss: 2.5732, Accuracy: 14.80%
# Epoch [1/5000], Batch [488/703], Loss: 2.5725, Accuracy: 14.81%
# Epoch [1/5000], Batch [489/703], Loss: 2.5720, Accuracy: 14.82%
# Epoch [1/5000], Batch [490/703], Loss: 2.5716, Accuracy: 14.83%
# Epoch [1/5000], Batch [491/703], Loss: 2.5710, Accuracy: 14.84%
# Epoch [1/5000], Batch [492/703], Loss: 2.5700, Accuracy: 14.85%
# Epoch [1/5000], Batch [493/703], Loss: 2.5693, Accuracy: 14.85%
# Epoch [1/5000], Batch [494/703], Loss: 2.5689, Accuracy: 14.88%
# Epoch [1/5000], Batch [495/703], Loss: 2.5682, Accuracy: 14.89%
# Epoch [1/5000], Batch [496/703], Loss: 2.5676, Accuracy: 14.91%
# Epoch [1/5000], Batch [497/703], Loss: 2.5666, Accuracy: 14.92%
# Epoch [1/5000], Batch [498/703], Loss: 2.5660, Accuracy: 14.93%
# Epoch [1/5000], Batch [499/703], Loss: 2.5651, Accuracy: 14.96%
# Epoch [1/5000], Batch [500/703], Loss: 2.5640, Accuracy: 14.98%
# Epoch [1/5000], Batch [538/703], Loss: 2.5430, Accuracy: 15.42%
# Epoch [1/5000], Batch [539/703], Loss: 2.5425, Accuracy: 15.42%
# Epoch [1/5000], Batch [540/703], Loss: 2.5422, Accuracy: 15.43%
# Epoch [1/5000], Batch [541/703], Loss: 2.5419, Accuracy: 15.43%
# Epoch [1/5000], Batch [542/703], Loss: 2.5412, Accuracy: 15.46%
# Epoch [1/5000], Batch [543/703], Loss: 2.5405, Accuracy: 15.47%
# Epoch [1/5000], Batch [544/703], Loss: 2.5402, Accuracy: 15.48%
# Epoch [1/5000], Batch [545/703], Loss: 2.5395, Accuracy: 15.50%
# Epoch [1/5000], Batch [546/703], Loss: 2.5388, Accuracy: 15.51%
# Epoch [1/5000], Batch [547/703], Loss: 2.5382, Accuracy: 15.52%
# Epoch [1/5000], Batch [548/703], Loss: 2.5381, Accuracy: 15.53%
# Epoch [1/5000], Batch [549/703], Loss: 2.5376, Accuracy: 15.53%
# Epoch [1/5000], Batch [550/703], Loss: 2.5375, Accuracy: 15.53%
# Epoch [1/5000], Batch [551/703], Loss: 2.5367, Accuracy: 15.55%
# Epoch [1/5000], Batch [552/703], Loss: 2.5365, Accuracy: 15.54%
# Epoch [1/5000], Batch [553/703], Loss: 2.5363, Accuracy: 15.55%
# Epoch [1/5000], Batch [554/703], Loss: 2.5357, Accuracy: 15.56%
# Epoch [1/5000], Batch [555/703], Loss: 2.5350, Accuracy: 15.57%
# Epoch [1/5000], Batch [556/703], Loss: 2.5344, Accuracy: 15.58%
# Epoch [1/5000], Batch [557/703], Loss: 2.5336, Accuracy: 15.61%
# Epoch [1/5000], Batch [558/703], Loss: 2.5333, Accuracy: 15.61%
# Epoch [1/5000], Batch [559/703], Loss: 2.5329, Accuracy: 15.61%
# Epoch [1/5000], Batch [560/703], Loss: 2.5326, Accuracy: 15.61%
# Epoch [1/5000], Batch [561/703], Loss: 2.5322, Accuracy: 15.62%
# Epoch [1/5000], Batch [562/703], Loss: 2.5319, Accuracy: 15.61%
# Epoch [1/5000], Batch [563/703], Loss: 2.5310, Accuracy: 15.63%
# Epoch [1/5000], Batch [564/703], Loss: 2.5305, Accuracy: 15.64%
# Epoch [1/5000], Batch [565/703], Loss: 2.5300, Accuracy: 15.65%
# Epoch [1/5000], Batch [566/703], Loss: 2.5299, Accuracy: 15.64%
# Epoch [1/5000], Batch [567/703], Loss: 2.5294, Accuracy: 15.66%
# Epoch [1/5000], Batch [568/703], Loss: 2.5287, Accuracy: 15.67%
# Epoch [1/5000], Batch [569/703], Loss: 2.5278, Accuracy: 15.69%
# Epoch [1/5000], Batch [570/703], Loss: 2.5272, Accuracy: 15.70%
# Epoch [1/5000], Batch [571/703], Loss: 2.5266, Accuracy: 15.72%
# Epoch [1/5000], Batch [572/703], Loss: 2.5261, Accuracy: 15.73%
# Epoch [1/5000], Batch [573/703], Loss: 2.5255, Accuracy: 15.73%
# Epoch [1/5000], Batch [574/703], Loss: 2.5253, Accuracy: 15.73%
# Epoch [1/5000], Batch [575/703], Loss: 2.5248, Accuracy: 15.74%
# Epoch [1/5000], Batch [576/703], Loss: 2.5243, Accuracy: 15.75%
# Epoch [1/5000], Batch [577/703], Loss: 2.5238, Accuracy: 15.76%
# Epoch [1/5000], Batch [578/703], Loss: 2.5233, Accuracy: 15.77%
# Epoch [1/5000], Batch [579/703], Loss: 2.5230, Accuracy: 15.78%
# Epoch [1/5000], Batch [580/703], Loss: 2.5223, Accuracy: 15.80%
# Epoch [1/5000], Batch [581/703], Loss: 2.5217, Accuracy: 15.82%
# Epoch [1/5000], Batch [582/703], Loss: 2.5213, Accuracy: 15.83%
# Epoch [1/5000], Batch [583/703], Loss: 2.5207, Accuracy: 15.83%
# Epoch [1/5000], Batch [584/703], Loss: 2.5203, Accuracy: 15.84%
# Epoch [1/5000], Batch [585/703], Loss: 2.5196, Accuracy: 15.86%
# Epoch [1/5000], Batch [586/703], Loss: 2.5190, Accuracy: 15.88%
# Epoch [1/5000], Batch [587/703], Loss: 2.5184, Accuracy: 15.88%
# Epoch [1/5000], Batch [588/703], Loss: 2.5179, Accuracy: 15.90%
# Epoch [1/5000], Batch [589/703], Loss: 2.5174, Accuracy: 15.92%
# Epoch [1/5000], Batch [590/703], Loss: 2.5169, Accuracy: 15.93%
# Epoch [1/5000], Batch [591/703], Loss: 2.5162, Accuracy: 15.95%
# Epoch [1/5000], Batch [592/703], Loss: 2.5157, Accuracy: 15.97%
# Epoch [1/5000], Batch [593/703], Loss: 2.5152, Accuracy: 15.96%
# Epoch [1/5000], Batch [594/703], Loss: 2.5149, Accuracy: 15.97%
# Epoch [1/5000], Batch [595/703], Loss: 2.5144, Accuracy: 15.98%
# Epoch [1/5000], Batch [596/703], Loss: 2.5139, Accuracy: 15.98%
# Epoch [1/5000], Batch [597/703], Loss: 2.5134, Accuracy: 15.99%
# Epoch [1/5000], Batch [598/703], Loss: 2.5129, Accuracy: 16.01%
# Epoch [1/5000], Batch [599/703], Loss: 2.5122, Accuracy: 16.03%
# Epoch [1/5000], Batch [600/703], Loss: 2.5120, Accuracy: 16.03%
# Epoch [1/5000], Batch [601/703], Loss: 2.5116, Accuracy: 16.04%
# Epoch [1/5000], Batch [602/703], Loss: 2.5110, Accuracy: 16.05%
# Epoch [1/5000], Batch [603/703], Loss: 2.5103, Accuracy: 16.06%
# Epoch [1/5000], Batch [604/703], Loss: 2.5099, Accuracy: 16.06%
# Epoch [1/5000], Batch [605/703], Loss: 2.5093, Accuracy: 16.08%
# Epoch [1/5000], Batch [606/703], Loss: 2.5086, Accuracy: 16.10%
# Epoch [1/5000], Batch [607/703], Loss: 2.5084, Accuracy: 16.10%
# Epoch [1/5000], Batch [608/703], Loss: 2.5076, Accuracy: 16.12%
# Epoch [1/5000], Batch [609/703], Loss: 2.5071, Accuracy: 16.15%
# Epoch [1/5000], Batch [610/703], Loss: 2.5068, Accuracy: 16.15%
# Epoch [1/5000], Batch [611/703], Loss: 2.5062, Accuracy: 16.16%
# Epoch [1/5000], Batch [649/703], Loss: 2.4882, Accuracy: 16.57%
# Epoch [1/5000], Batch [650/703], Loss: 2.4876, Accuracy: 16.59%
# Epoch [1/5000], Batch [651/703], Loss: 2.4869, Accuracy: 16.60%
# Epoch [1/5000], Batch [652/703], Loss: 2.4862, Accuracy: 16.62%
# Epoch [1/5000], Batch [653/703], Loss: 2.4857, Accuracy: 16.65%
# Epoch [1/5000], Batch [654/703], Loss: 2.4851, Accuracy: 16.66%
# Epoch [1/5000], Batch [655/703], Loss: 2.4846, Accuracy: 16.67%
# Epoch [1/5000], Batch [656/703], Loss: 2.4842, Accuracy: 16.70%
# Epoch [1/5000], Batch [657/703], Loss: 2.4839, Accuracy: 16.70%
# Epoch [1/5000], Batch [658/703], Loss: 2.4835, Accuracy: 16.69%
# Epoch [1/5000], Batch [659/703], Loss: 2.4831, Accuracy: 16.70%
# Epoch [1/5000], Batch [660/703], Loss: 2.4824, Accuracy: 16.72%
# Epoch [1/5000], Batch [661/703], Loss: 2.4818, Accuracy: 16.74%
# Epoch [1/5000], Batch [662/703], Loss: 2.4815, Accuracy: 16.75%
# Epoch [1/5000], Batch [663/703], Loss: 2.4809, Accuracy: 16.78%
# Epoch [1/5000], Batch [664/703], Loss: 2.4807, Accuracy: 16.78%
# Epoch [1/5000], Batch [665/703], Loss: 2.4804, Accuracy: 16.80%
# Epoch [1/5000], Batch [666/703], Loss: 2.4799, Accuracy: 16.79%
# Epoch [1/5000], Batch [667/703], Loss: 2.4792, Accuracy: 16.81%
# Epoch [1/5000], Batch [668/703], Loss: 2.4786, Accuracy: 16.82%
# Epoch [1/5000], Batch [669/703], Loss: 2.4780, Accuracy: 16.85%
# Epoch [1/5000], Batch [670/703], Loss: 2.4774, Accuracy: 16.87%
# Epoch [1/5000], Batch [671/703], Loss: 2.4770, Accuracy: 16.86%
# Epoch [1/5000], Batch [672/703], Loss: 2.4765, Accuracy: 16.87%
# Epoch [1/5000], Batch [673/703], Loss: 2.4758, Accuracy: 16.89%
# Epoch [1/5000], Batch [674/703], Loss: 2.4755, Accuracy: 16.91%
# Epoch [1/5000], Batch [675/703], Loss: 2.4750, Accuracy: 16.92%
# Epoch [1/5000], Batch [676/703], Loss: 2.4745, Accuracy: 16.93%
# Epoch [1/5000], Batch [677/703], Loss: 2.4739, Accuracy: 16.95%
# Epoch [1/5000], Batch [678/703], Loss: 2.4734, Accuracy: 16.96%
# Epoch [1/5000], Batch [679/703], Loss: 2.4732, Accuracy: 16.97%
# Epoch [1/5000], Batch [680/703], Loss: 2.4729, Accuracy: 16.97%
# Epoch [1/5000], Batch [681/703], Loss: 2.4724, Accuracy: 16.97%
# Epoch [1/5000], Batch [682/703], Loss: 2.4722, Accuracy: 16.98%
# Epoch [1/5000], Batch [683/703], Loss: 2.4718, Accuracy: 16.97%
# Epoch [1/5000], Batch [684/703], Loss: 2.4715, Accuracy: 16.98%
# Epoch [1/5000], Batch [685/703], Loss: 2.4712, Accuracy: 16.98%
# Epoch [15/5000], Batch [683/703], Loss: 0.8953, Accuracy: 69.74%
# Epoch [15/5000], Batch [684/703], Loss: 0.8950, Accuracy: 69.75%
# Epoch [15/5000], Batch [685/703], Loss: 0.8954, Accuracy: 69.74%
# Epoch [15/5000], Batch [686/703], Loss: 0.8951, Accuracy: 69.75%
# Epoch [15/5000], Batch [687/703], Loss: 0.8951, Accuracy: 69.76%
# Epoch [15/5000], Batch [688/703], Loss: 0.8952, Accuracy: 69.76%
# Epoch [15/5000], Batch [689/703], Loss: 0.8954, Accuracy: 69.74%
# Epoch [15/5000], Batch [690/703], Loss: 0.8956, Accuracy: 69.74%
# Epoch [15/5000], Batch [691/703], Loss: 0.8957, Accuracy: 69.74%
# Epoch [15/5000], Batch [692/703], Loss: 0.8956, Accuracy: 69.74%
# Epoch [15/5000], Batch [693/703], Loss: 0.8959, Accuracy: 69.74%
# Epoch [15/5000], Batch [694/703], Loss: 0.8959, Accuracy: 69.74%
# Epoch [15/5000], Batch [695/703], Loss: 0.8957, Accuracy: 69.74%
# Epoch [15/5000], Batch [696/703], Loss: 0.8963, Accuracy: 69.72%
# Epoch [15/5000], Batch [697/703], Loss: 0.8961, Accuracy: 69.72%
# Epoch [15/5000], Batch [698/703], Loss: 0.8960, Accuracy: 69.73%
# Epoch [15/5000], Batch [699/703], Loss: 0.8960, Accuracy: 69.72%
# Epoch [15/5000], Batch [700/703], Loss: 0.8962, Accuracy: 69.72%
# Epoch [15/5000], Batch [701/703], Loss: 0.8961, Accuracy: 69.72%
# Epoch [15/5000], Batch [702/703], Loss: 0.8961, Accuracy: 69.73%
# Epoch [15/5000], Batch [703/703], Loss: 0.8963, Accuracy: 69.72%

# %% [markdown]
# ## Inference on data
#
# This is useful for analysis but is entirely optional

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    img = numpy.clip(img, 0, 1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    img = numpy.transpose(img, (1, 2, 0))
    plt.imshow(img)

    predicted_label = numpy.argmax(predictions_array)
    color = '#335599' if predicted_label == true_label else '#ee4433'

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                  100*numpy.max(predictions_array),
                                  class_names[true_label]),
                                  color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot = plt.bar(range(20), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = numpy.argmax(predictions_array)

    thisplot[predicted_label].set_color('#ee4433')
    thisplot[true_label].set_color('#335599')

test_images, test_labels = next(test_iterator)
test_images, test_labels = test_images.to(device), test_labels.to(device)
test_preds = torch.softmax(N(test_images), dim=1).data.cpu().numpy()
num_rows = 8
num_cols = 4
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, test_preds, test_labels.cpu().numpy(), test_images.cpu().numpy()) # Used .numpy() here
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, test_preds, test_labels.cpu().numpy())
